# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv('Uber-Jan-Feb-FOIL.csv')

# %%
data.head()
# Out:
#   dispatching_base_number      date  active_vehicles  trips
# 0                  B02512  1/1/2015              190   1132
# 1                  B02765  1/1/2015              225   1765
# 2                  B02764  1/1/2015             3427  29421
# 3                  B02682  1/1/2015              945   7679
# 4                  B02617  1/1/2015             1228   9537

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354 entries, 0 to 353
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   dispatching_base_number  354 non-null    object
#  1   date                     354 non-null    object
#  2   active_vehicles          354 non-null    int64
#  3   trips                    354 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 11.2+ KB

# %%
data.isnull().sum()
# Out:
# dispatching_base_number    0
# date                       0
# active_vehicles            0
# trips                      0
# dtype: int64

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data['Day'] = data['date'].dt.day
data['DayOfWeek'] = data['date'].dt.dayofweek
data['Month'] = data['date'].dt.month

# %%
print(data['Month'], data['Day'])
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 349    2
# 350    2
# 351    2
# 352    2
# 353    2
# Name: Month, Length: 354, dtype: int32 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 349    28
# 350    28
# 351    28
# 352    28
# 353    28
# Name: Day, Length: 354, dtype: int32

# %%
plt.figure(figsize=(8,6))
plt.plot(df_unique['active_vehicles'], df_unique['trips'],
         marker='o')
plt.title('Line Plot between Active Vehicles and Trips')
plt.xlabel('active_vehicles')
plt.ylabel('trips')
plt.grid(True)
plt.show()

# %%
df = pd.DataFrame(data)

# %%
df_unique = df.drop_duplicates(subset='date', keep='first')
print(df_unique)
# Out:
#     dispatching_base_number       date  active_vehicles  trips  Day  \
# 0                    B02512 2015-01-01              190   1132    1
# 6                    B02598 2015-01-02              785   4768    2
# 12                   B02765 2015-01-03              201   1526    3
# 18                   B02512 2015-01-04              147    791    4
# 24                   B02512 2015-01-05              194    984    5
# 30                   B02764 2015-01-06             3473  25301    6
# 36                   B02617 2015-01-07             1363  11528    7
# 42                   B02765 2015-01-08              262   1911    8
# 48                   B02617 2015-01-09             1455  13165    9
# 54                   B02682 2015-01-10             1057  11629   10
# 60                   B02765 2015-01-11              220   1672   11
# 66                   B02764 2015-01-12             3499  26852   12
# 72                   B02765 2015-01-13              258   1697   13
# ...

# %%
plt.figure(figsize=(8,6))
plt.plot(df_unique['date'], df_unique['trips'],
         marker='o')
plt.title('Line Plot between Date and Trips')
plt.xlabel('date')
plt.ylabel('trips')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize =(11,6))
sns.histplot(data = df_unique,x = 'trips', color = 'orange', edgecolor = 'linen', alpha = 0.5, bins =5)

plt.title("Histogram of Trips")
plt.xlabel('trips')
plt.ylabel('Count')

plt.show()

# %%
plt.figure(figsize =(11,6))
sns.histplot(data = df_unique,x = 'active_vehicles', color = 'red', edgecolor = 'linen', alpha = 0.5, bins =5)

plt.title("Histogram of Active Vehicles")
plt.xlabel('active_vehicles')
plt.ylabel('Count')
plt.show()

# %%
df_unique['trips'].value_counts().index[0]
# Out:
# 1132

# %%
round(data['trips'].mean(),2)
# Out:
# 11667.32

# %%
data['trips'].median()
# Out:
# 9601.0

# %%
data['active_vehicles'].median()
# Out:
# 1077.0

# %%
round(data['active_vehicles'].mean(),2)
# Out:
# 1307.44

# %%
plt.figure(figsize=(8,6))
plt.plot(df_unique['date'], df_unique['active_vehicles'],
         marker='o')
plt.title('Line Plot between Date and Trips')
plt.xlabel('date')
plt.ylabel('active vehicles')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(df_unique['dispatching_base_number'], df_unique['trips'],
         marker='o')
plt.title('Line Plot between dispatching_base_number  and Trips')
plt.xlabel('dispatching_base_number')
plt.ylabel('trips')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(df_unique['dispatching_base_number'], df_unique['active_vehicles'],
         marker='o')
plt.title('Line Plot between dispatching_base_number  and active vehicles')
plt.xlabel('dispatching_base_number')
plt.ylabel('active vehicles')
plt.grid(True)
plt.show()
